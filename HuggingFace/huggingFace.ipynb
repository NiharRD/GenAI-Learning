# %%
from dotenv import load_dotenv
load_dotenv()
import os
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ['HUGGINGFACEHUB_API_TOKEN']=os.getenv("HUGGINGFACEHUB_API_TOKEN" )

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma

# %%
documentLoader=PyPDFLoader("BTPMaterials.pdf")
documents=documentLoader.load()
docs=RecursiveCharacterTextSplitter(chunk_size=1000,chunk_overlap=200).split_documents(documents)
embeddings=OpenAIEmbeddings()
vectordb=Chroma.from_documents(docs,embeddings)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
len(docs)
# Out:
# 349

# %%
import numpy as np 
arr=np.array(embeddings.embed_query("What are seismic waves?"))
arr
# Out:
# array([-0.0024237 , -0.00625292,  0.00308233, ..., -0.00621696,
#        -0.00763555, -0.0146566 ])

# %%
store=Chroma.from_documents(docs,embeddings)
# Out:
# Failed to send telemetry event ClientStartEvent: capture() takes 1 positional argument but 3 were given
# Failed to send telemetry event ClientCreateCollectionEvent: capture() takes 1 positional argument but 3 were given

# %%
query="WHAT IS   Standard?"
relevant_documents=store.similarity_search(query)

print(relevant_documents[0].page_content)
# Out:
# ANNEX A
# (Clause 2)
# LIST OF REFERRED STANDARDS
#
# IS No.  Title
# IS 456 : 2000  Plain and reinforced concrete
# — Code of practice  (fourth
# revision )
# IS 800 : 2007  General construction in steel
# — Code of practice (third
# revision )
# IS 875  Code of practice for design
# loads (other than earthquake)
# for buildings and structures
# — Code of practice :
# (Part 1 ) : 1987  Dead loads  — Unit weights
# of building materials and
# stored materials ( second
# revision )
# (Part 2 ) : 1987  Imposed loads ( second
# revision )
#   (Part 3 ) : 2015  Wind loads ( third revision )
# (Part 4 ) : 1987  Snow loads ( second revision )
# (Part 5 ) : 1987  Special loads and load
# combinations (second
# revision )
# IS 1343 : 2012 Prestressed concrete — Code
# of practice (second revision )
# IS 1893  Design earthquake hazard
# and criteria for earthquake -
# resistant  design of structures
# — Code of practice :
# (Part 2) : 2025  Liquid -retaining structures
# (under preparation )

# %% [markdown]
# HuggingFace Starts
# The Hugging Face Hub is an platform with over 350k models, 75k datasets, and 150k demo apps (Spaces), all open source and publicly available, in an online platform where people can easily collaborate and build ML together.

# %%
from langchain_community.llms import HuggingFaceHub

hf = HuggingFaceHub(
    repo_id="google/flan-t5-large",  # Use a model that works reliably
    model_kwargs={"temperature":0.1, "max_length":512}
)

query = "What is the health insurance coverage?"
response = hf.invoke(query)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[26], line 3
#       1 from langchain_community.llms import HuggingFaceHub
# ----> 3 hf = HuggingFaceHub(
#       4     repo_id="google/flan-t5-large",  # Use a model that works reliably
#       5     model_kwargs={"temperature":0.1, "max_length":512}
#       6 )
#       8 query = "What is the health insurance coverage?"
#       9 response = hf.invoke(query)
#
# File ~/Desktop/GenAI/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:183, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     181     warned = True
#     182     emit_warning()
# --> 183 return wrapped(self, *args, **kwargs)
#
# File ~/Desktop/GenAI/venv/lib/python3.10/site-packages/langchain_core/load/serializable.py:120, in Serializable.__init__(self, **kwargs)
# ...
